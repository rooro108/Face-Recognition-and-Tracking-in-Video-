# %%
import numpy as np
from scipy.spatial.distance import cosine

print("✅ numpy:", np.__version__)
print("✅ scipy:", __import__("scipy").__version__)
# Out:
# ✅ numpy: 2.0.2
# ✅ scipy: 1.16.1

# %%
# !pip install --upgrade pip

# تثبيت numpy نسخة متوافقة
# !pip uninstall -y numpy
# !pip install numpy==1.26.4

# تثبيت باكجات PyTorch
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# مكتبات أساسية
# !pip install facenet-pytorch
# !pip install opencv-python
# !pip install deep-sort-realtime
# !pip install scipy==1.11.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 116.0 MB/s  0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
# ...

# %%
import os

base_dir = "/content/drive/MyDrive/FaceDataset"
names = ["ali", "sara"]

for name in names:
    path = os.path.join(base_dir, name)
    os.makedirs(path, exist_ok=True)
    print(f"📁 تم إنشاء المجلد: {path}")
# Out:
# 📁 تم إنشاء المجلد: /content/drive/MyDrive/FaceDataset/ali
# 📁 تم إنشاء المجلد: /content/drive/MyDrive/FaceDataset/sara

# %%
# !pip uninstall -y numpy opencv-python opencv-python-headless
# !pip install numpy==1.26.4
# !pip install opencv-python-headless==4.8.0.76
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: opencv-python 4.12.0.88
# Uninstalling opencv-python-4.12.0.88:
#   Successfully uninstalled opencv-python-4.12.0.88
# Found existing installation: opencv-python-headless 4.12.0.88
# Uninstalling opencv-python-headless-4.12.0.88:
#   Successfully uninstalled opencv-python-headless-4.12.0.88
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deep-sort-realtime 1.3.2 requires opencv-python, which is not installed.
# dopamine-rl 4.1.2 requires opencv-python>=3.4.8.29, which is not installed.
# ...

# %%
# !wget -O /content/input.mp4 https://raw.githubusercontent.com/intel-iot-devkit/sample-videos/master/face-demographics-walking.mp4
# Out:
# --2025-09-08 13:00:49--  https://raw.githubusercontent.com/intel-iot-devkit/sample-videos/master/face-demographics-walking.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6406124 (6.1M) [application/octet-stream]
# Saving to: ‘/content/input.mp4’
#
# /content/input.mp4  100%[===================>]   6.11M  --.-KB/s    in 0.02s
#
# 2025-09-08 13:00:50 (304 MB/s) - ‘/content/input.mp4’ saved [6406124/6406124]

# %%
import os

DATASET_DIR = "/content/drive/MyDrive/FaceDataset"
KNOWN_PERSONS = ["ali", "sara"]

for person in KNOWN_PERSONS:
    person_dir = os.path.join(DATASET_DIR, person)
    if not os.path.exists(person_dir):
        print(f"❌ Folder not found: {person_dir}")
    else:
        files = [f for f in os.listdir(person_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        if not files:
            print(f"⚠️ No image files found in {person_dir}")
        else:
            print(f"✅ Found {len(files)} images for {person}")
# Out:
# ✅ Found 4 images for ali
# ✅ Found 9 images for sara

# %%
# !pip install numpy==1.23.5 opencv-python-headless==4.8.0.74 --force-reinstall
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 98.7 MB/s  0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install Pillow==9.5.0 --force-reinstall
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 MB 46.3 MB/s  0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'Pillow' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'Pillow'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for Pillow: filename=Pillow-9.5.0-cp312-cp312-linux_x86_64.whl size=1210267 sha256=41f8925e5fd0baae0fa16dde5858bb3498f251f4184decaf755aa07a30b58845
#   Stored in directory: /root/.cache/pip/wheels/ea/de/2e/75a6399e5d8cd3a55c13c8f0658d996d4ce4cff37389de044c
# Successfully built Pillow
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
# ...

# %%
import os
import cv2
import numpy as np
from PIL import Image
from scipy.spatial.distance import cosine
import torch
from facenet_pytorch import MTCNN, InceptionResnetV1
# from facenet_pytorch import MTCNN, InceptionResnetV1

# ========== إعدادات ==========
INPUT_VIDEO = "/content/input.mp4"
OUTPUT_VIDEO = "/content/output_labeled.mp4"
DATASET_DIR = "/content/drive/MyDrive/FaceDataset"
SIGNATURE = "Implemented by: Reem Almulhem"
SIMILARITY_THRESHOLD = 0.60  # ✅ فقط من تتجاوز هذه النسبة يعتبر معروف

# ========== الجهاز ==========
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ========== تحميل النماذج ==========
mtcnn = MTCNN(keep_all=True, image_size=160, margin=20, device=device)
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# ========== تحميل الوجوه ==========
known_faces = {}  # {person: [emb1, emb2, ...]}

for person_name in ["ali", "sara"]:
    person_dir = os.path.join(DATASET_DIR, person_name)
    embeddings = []

    if os.path.isdir(person_dir):
        for file_name in os.listdir(person_dir):
            file_path = os.path.join(person_dir, file_name)
            try:
                img = Image.open(file_path).convert("RGB")
                face = mtcnn(img)
                if face is not None:
                    if face.ndim == 3:
                        face = face.unsqueeze(0)
                    elif face.ndim > 4:
                        continue

                    emb = resnet(face.to(device)).detach().cpu().numpy().flatten()
                    embeddings.append(emb)
            except Exception as e:
                print(f"❌ Error loading {file_name}: {e}")

    if embeddings:
        known_faces[person_name] = embeddings
        print(f"✅ Loaded {len(embeddings)} embeddings for {person_name}")
    else:
        print(f"⚠️ No valid faces found for {person_name}")

# ========== معالجة الفيديو ==========
cap = cv2.VideoCapture(INPUT_VIDEO)
fps = cap.get(cv2.CAP_PROP_FPS) or 10
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

frame_idx = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame_idx += 1

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb)
    boxes, _ = mtcnn.detect(pil_img)
    faces = mtcnn(pil_img)

    if boxes is not None and faces is not None:
        for i, face in enumerate(faces):
            if face is None:
                continue

            if face.ndim == 3:
                face = face.unsqueeze(0)
            elif face.ndim > 4:
                continue

            emb = resnet(face.to(device)).detach().cpu().numpy().flatten()

            # مقارنة مع الوجوه المعروفة
            best_similarity = 0.0
            matched_person = None

            for person, embs in known_faces.items():
                for known_emb in embs:
                    dist = cosine(emb, known_emb)
                    similarity = 1 - dist
                    if similarity > best_similarity:
                        best_similarity = similarity
                        matched_person = person

            if matched_person and best_similarity >= SIMILARITY_THRESHOLD:
                name = f"Known: {matched_person.capitalize()}"
                label = f"{name} ({best_similarity:.2%})"
                color = (0, 255, 0)
            else:
                label = "Unknown"
                color = (0, 0, 255)

            x1, y1, x2, y2 = map(int, boxes[i])
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)

    # التوقيع
    cv2.putText(frame, SIGNATURE, (10, h - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    out.write(frame)

cap.release()
out.release()
print("🎬 تم حفظ الفيديو النهائي:", OUTPUT_VIDEO)
# Out:
#   0%|          | 0.00/107M [00:00<?, ?B/s]
# ✅ Loaded 4 embeddings for ali
# ✅ Loaded 9 embeddings for sara
# 🎬 تم حفظ الفيديو النهائي: /content/output_labeled.mp4

# %%
import os
import cv2
import numpy as np
from PIL import Image
from scipy.spatial.distance import cosine
import torch
from facenet_pytorch import MTCNN, InceptionResnetV1
from datetime import timedelta
import csv

# ========== إعدادات ==========
INPUT_VIDEO = "/content/input.mp4"
OUTPUT_VIDEO = "/content/output_labeled.mp4"
DATASET_DIR = "/content/drive/MyDrive/FaceDataset"
SIGNATURE = "Implemented by: Reem Almulhem"
SIMILARITY_THRESHOLD = 0.60

# ========== الجهاز ==========
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ========== تحميل النماذج ==========
mtcnn = MTCNN(keep_all=True, image_size=160, margin=20, device=device)
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# ========== تحميل الوجوه ==========
known_faces = {}
for person_name in ["ali", "sara"]:
    person_dir = os.path.join(DATASET_DIR, person_name)
    embeddings = []
    if os.path.isdir(person_dir):
        for file_name in os.listdir(person_dir):
            file_path = os.path.join(person_dir, file_name)
            try:
                img = Image.open(file_path).convert("RGB")
                face = mtcnn(img)
                if face is not None:
                    if face.ndim == 3:
                        face = face.unsqueeze(0)
                    elif face.ndim > 4:
                        continue
                    emb = resnet(face.to(device)).detach().cpu().numpy().flatten()
                    embeddings.append(emb)
            except Exception as e:
                print(f"❌ Error loading {file_name}: {e}")
    if embeddings:
        known_faces[person_name] = embeddings
        print(f"✅ Loaded {len(embeddings)} embeddings for {person_name}")
    else:
        print(f"⚠️ No valid faces found for {person_name}")

# ========== إعداد الفيديو ==========
cap = cv2.VideoCapture(INPUT_VIDEO)
fps = cap.get(cv2.CAP_PROP_FPS) or 10
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

# ========== سجلات الأحداث ==========
active_people = {}   # {person: frame_start}
logs = []            # [ [timestamp, event, person, duration] ]

frame_idx = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame_idx += 1
    current_time = timedelta(seconds=frame_idx / fps)

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb)
    boxes, _ = mtcnn.detect(pil_img)
    faces = mtcnn(pil_img)

    detected_people = set()

    if boxes is not None and faces is not None:
        for i, face in enumerate(faces):
            if face is None:
                continue
            if face.ndim == 3:
                face = face.unsqueeze(0)
            elif face.ndim > 4:
                continue

            emb = resnet(face.to(device)).detach().cpu().numpy().flatten()

            best_similarity = 0.0
            matched_person = None
            for person, embs in known_faces.items():
                for known_emb in embs:
                    dist = cosine(emb, known_emb)
                    similarity = 1 - dist
                    if similarity > best_similarity:
                        best_similarity = similarity
                        matched_person = person

            if matched_person and best_similarity >= SIMILARITY_THRESHOLD:
                label = f"{matched_person.capitalize()} ({best_similarity:.2%})"
                color = (0, 255, 0)
                detected_people.add(matched_person)
            else:
                label = "Unknown"
                color = (0, 0, 255)

            x1, y1, x2, y2 = map(int, boxes[i])
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)

    # ====== تسجيل الدخول/الخروج ======
    for person in detected_people:
        if person not in active_people:
            # ظهر لأول مرة أو عاد بعد غياب
            active_people[person] = frame_idx
            logs.append([str(current_time), "Appeared", person, ""])
    for person in list(active_people.keys()):
        if person not in detected_people:
            start_frame = active_people.pop(person)
            duration = (frame_idx - start_frame) / fps
            logs.append([str(current_time), "Disappeared", person, f"{duration:.2f} sec"])

    # التوقيع
    cv2.putText(frame, SIGNATURE, (10, h - 20),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    out.write(frame)

cap.release()
out.release()
print("🎬 تم حفظ الفيديو النهائي:", OUTPUT_VIDEO)

# ========== إخراج السجل ==========
print("\n📌 سجل الأحداث:")
if logs:
    for row in logs:
        print(row)
else:
    print("⚠️ لا توجد أحداث مسجلة.")

LOG_FILE = "/content/logs.csv"
with open(LOG_FILE, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Timestamp", "Event", "Person", "Duration"])
    writer.writerows(logs)

print(f"\n📝 تم حفظ السجل في ملف: {LOG_FILE}")
# Out:
# ✅ Loaded 4 embeddings for ali
# ✅ Loaded 9 embeddings for sara
# 🎬 تم حفظ الفيديو النهائي: /content/output_labeled.mp4
#
# 📌 سجل الأحداث:
# ['0:00:03.583333', 'Appeared', 'ali', '']
# ['0:00:09.083333', 'Disappeared', 'ali', '5.50 sec']
# ['0:00:09.166667', 'Appeared', 'ali', '']
# ['0:00:09.250000', 'Disappeared', 'ali', '0.08 sec']
# ['0:00:09.416667', 'Appeared', 'ali', '']
# ['0:00:09.583333', 'Disappeared', 'ali', '0.17 sec']
# ['0:00:39.666667', 'Appeared', 'sara', '']
# ['0:00:39.833333', 'Disappeared', 'sara', '0.17 sec']
# ['0:00:53.416667', 'Appeared', 'sara', '']
# ['0:00:53.750000', 'Disappeared', 'sara', '0.33 sec']
# ['0:00:54', 'Appeared', 'sara', '']
# ['0:00:54.166667', 'Disappeared', 'sara', '0.17 sec']
# ['0:00:54.250000', 'Appeared', 'sara', '']
# ['0:00:57.916667', 'Disappeared', 'sara', '3.67 sec']
#
# 📝 تم حفظ السجل في ملف: /content/logs.csv

# %%
import os
import cv2
import numpy as np
from PIL import Image
from scipy.spatial.distance import cosine
import torch
from facenet_pytorch import MTCNN, InceptionResnetV1
from datetime import timedelta
import csv

# ========== إعدادات ==========
INPUT_VIDEO = "/content/input.mp4"
OUTPUT_VIDEO = "/content/output_labeled.mp4"
CSV_LOG = "/content/event_log.csv"
DATASET_DIR = "/content/drive/MyDrive/FaceDataset"
SIGNATURE = "Implemented by: Reem Almulhem"
SIMILARITY_THRESHOLD = 0.60  # ✅ فقط من تتجاوز هذه النسبة يعتبر معروف

# ========== الجهاز ==========
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ========== تحميل النماذج ==========
mtcnn = MTCNN(keep_all=True, image_size=160, margin=20, device=device)
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# ========== تحميل الوجوه ==========
known_faces = {}  # {person: [emb1, emb2, ...]}

for person_name in ["ali", "sara"]:
    person_dir = os.path.join(DATASET_DIR, person_name)
    embeddings = []

    if os.path.isdir(person_dir):
        for file_name in os.listdir(person_dir):
            file_path = os.path.join(person_dir, file_name)
            try:
                img = Image.open(file_path).convert("RGB")
                face = mtcnn(img)
                if face is not None:
                    if face.ndim == 3:
                        face = face.unsqueeze(0)
                    elif face.ndim > 4:
                        continue

                    emb = resnet(face.to(device)).detach().cpu().numpy().flatten()
                    embeddings.append(emb)
            except Exception as e:
                print(f"❌ Error loading {file_name}: {e}")

    if embeddings:
        known_faces[person_name] = embeddings
        print(f"✅ Loaded {len(embeddings)} embeddings for {person_name}")
    else:
        print(f"⚠️ No valid faces found for {person_name}")

# ========== تتبع الأحداث ==========
active_people = {}  # {person: frame_index}
event_log = []      # [time, event, person, duration]

def frame_to_time(frame_idx, fps):
    return str(timedelta(seconds=frame_idx / fps))

# ========== معالجة الفيديو ==========
cap = cv2.VideoCapture(INPUT_VIDEO)
fps = cap.get(cv2.CAP_PROP_FPS) or 10
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

frame_idx = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame_idx += 1

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb)
    boxes, _ = mtcnn.detect(pil_img)
    faces = mtcnn(pil_img)

    current_detected = set()

    if boxes is not None and faces is not None:
        for i, face in enumerate(faces):
            if face is None:
                continue

            if face.ndim == 3:
                face = face.unsqueeze(0)
            elif face.ndim > 4:
                continue

            emb = resnet(face.to(device)).detach().cpu().numpy().flatten()

            # مقارنة مع الوجوه المعروفة
            best_similarity = 0.0
            matched_person = None

            for person, embs in known_faces.items():
                for known_emb in embs:
                    dist = cosine(emb, known_emb)
                    similarity = 1 - dist
                    if similarity > best_similarity:
                        best_similarity = similarity
                        matched_person = person

            if matched_person and best_similarity >= SIMILARITY_THRESHOLD:
                person_label = matched_person
                label = f"Known: {matched_person.capitalize()} ({best_similarity:.2%})"
                color = (0, 255, 0)
            else:
                person_label = "Unknown"
                label = f"Unknown"
                color = (0, 0, 255)

            current_detected.add(person_label)

            x1, y1, x2, y2 = map(int, boxes[i])
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)

    # سجل الظهور والاختفاء
    for person in list(active_people.keys()):
        if person not in current_detected:
            start_frame = active_people.pop(person)
            duration = (frame_idx - start_frame) / fps
            event_log.append([frame_to_time(frame_idx, fps), "Disappeared", person, f"{duration:.2f} sec"])

    for person in current_detected:
        if person not in active_people:
            active_people[person] = frame_idx
            event_log.append([frame_to_time(frame_idx, fps), "Appeared", person, ""])

    # التوقيع
    cv2.putText(frame, SIGNATURE, (10, h - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    out.write(frame)

cap.release()
out.release()

# ========== حفظ السجل ==========
with open(CSV_LOG, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Time", "Event", "Person", "Duration"])
    writer.writerows(event_log)

print("🎬 تم حفظ الفيديو النهائي:", OUTPUT_VIDEO)
print("📂 تم حفظ سجل الأحداث في:", CSV_LOG)
# Out:
# ✅ Loaded 4 embeddings for ali
# ✅ Loaded 9 embeddings for sara
# 🎬 تم حفظ الفيديو النهائي: /content/output_labeled.mp4
# 📂 تم حفظ سجل الأحداث في: /content/event_log.csv
